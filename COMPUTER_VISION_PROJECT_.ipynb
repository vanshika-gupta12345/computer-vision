# %%
# !pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.11/dist-packages (4.11.0.86)
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.11/dist-packages (from opencv-python) (2.0.2)

# %%
import cv2
import numpy as np

# %%
img = cv2.imread('/content/building.jpg')

# %%
import cv2
from google.colab.patches import cv2_imshow

img = cv2.imread('/content/building.jpg') #read an image

# Use cv2_imshow instead of cv2.imshow in Google Colab
cv2_imshow(img)
# cv2.waitkey(0) # Not needed with cv2_imshow in Colab
# cv2.destroyAllWindows() # Not needed with cv2_imshow in Colab
# Out:
# <PIL.Image.Image image mode=RGB size=240x180>

# %%
img = cv2.imread('/content/building.jpg',0)

cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=L size=240x180>

# %%
# Reload the image in color mode to ensure it has 3 dimensions
img = cv2.imread('/content/building.jpg')

# Check if the image was loaded successfully in color
# Access and modify the blue channel (index 0 in BGR)
# This line is kept from your original problematic cell, although the error was on index 2
# We will also include the line causing the error (index 2) to ensure both work

img[:,:,2]=0 # This was the line causing the IndexError in your traceback
cv2_imshow(img)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=240x180>

# %%
# Reload the image in color mode to ensure it has 3 dimensions
img = cv2.imread('/content/building.jpg')

# Check if the image was loaded successfully in color
# Access and modify the blue channel (index 0 in BGR)
# This line is kept from your original problematic cell, although the error was on index 2
# We will also include the line causing the error (index 2) to ensure both work

img[:,:,0]=0 # This was the line causing the IndexError in your traceback
cv2_imshow(img)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=240x180>

# %%
# Reload the image in color mode to ensure it has 3 dimensions
img = cv2.imread('/content/building.jpg')

# Check if the image was loaded successfully in color
# Access and modify the blue channel (index 0 in BGR)
# This line is kept from your original problematic cell, although the error was on index 2
# We will also include the line causing the error (index 2) to ensure both work

img[:,:,1]=0 # This was the line causing the IndexError in your traceback
cv2_imshow(img)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=240x180>

# %%
# Load the image in color mode (BGR is the default)
img = cv2.imread('/content/building.jpg')

# Check if the image was loaded successfully
if img is not None:
    # Access and modify the blue channel (index 0 in BGR)
    img[:,:,0]=0
    cv2_imshow(img)
    # cv2.waitKey(0) # Not needed with cv2_imshow in Colab
    # cv2.destroyAllWindows() # Not needed with cv2_imshow in Colab
else:
    print("Error loading image.")
# Out:
# <PIL.Image.Image image mode=RGB size=240x180>

# %%
img = cv2.imread('/content/building.jpg')

img = cv2.resize(img, (0, 0), fx=0.5, fy=0.5) #resize the image

cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=120x90>

# %%
img = cv2.imread('/content/building.jpg')
img = cv2.rotate(img, cv2.ROTATE_90_COUNTERCLOCKWISE)

cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=180x240>

# %%
img = cv2.rotate(img, cv2.ROTATE_90_CLOCKWISE)

cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=240x180>

# %%
img = cv2.rotate(img, cv2.ROTATE_180)

cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=240x180>

# %%
cv2.imwrite('rotated_image.jpg', img)
# Out:
# True

# %%
cv2.imwrite('new_img.jpg', img)
# Out:
# True

# %%
print(img)

#BLUE GREEN RED  (RGB)
print(img)

#BLUE GREEN RED  (RGB)

[0,0,0]
[255, 252, 252]
[255, 252, 252]
# Out:
# [[[135  96 112]
#   [111  78  99]
#   [ 77  58  85]
#   ...
#   [ 58  25   9]
#   [ 45  25   7]
#   [ 65  49  32]]
#
#  [[138  99 115]
#   [118  85 106]
#   [ 89  70  97]
#   ...
#   [ 59  26  10]
#   [ 48  28  10]
#   [ 61  45  28]]
#
#  [[111  72  88]
#   [116  83 104]
#   [ 98  79 106]
#   ...
#   [ 60  27  11]
#   [ 52  32  14]
#   [ 57  41  24]]
#
#  ...
#
#  [[255 250 191]
#   [184 176 117]
#   [ 70  62   3]
#   ...
#   [ 76  61  52]
#   [105  92  84]
#   [134 122 116]]
#
#  [[164 157 100]
#   [ 60  51   0]
#   [172 163 106]
#   ...
#   [143 132 124]
#   [163 153 146]
#   [178 167 163]]
#
#  [[ 66  59   4]
#   [125 115  61]
#   [238 228 174]
#   ...
#   [172 160 154]
#   [129 121 114]
#   [ 96  87  83]]]
# [[[135  96 112]
#   [111  78  99]
#   [ 77  58  85]
#   ...
#   [ 58  25   9]
#   [ 45  25   7]
#   [ 65  49  32]]
#
#  [[138  99 115]
#   [118  85 106]
#   [ 89  70  97]
#   ...
#   [ 59  26  10]
#   [ 48  28  10]
#   [ 61  45  28]]
#
#  [[111  72  88]
#   [116  83 104]
#   [ 98  79 106]
#   ...
#   [ 60  27  11]
#   [ 52  32  14]
#   [ 57  41  24]]
#
#  ...
#
#  [[255 250 191]
#   [184 176 117]
#   [ 70  62   3]
#   ...
#   [ 76  61  52]
#   [105  92  84]
#   [134 122 116]]
#
#  [[164 157 100]
#   [ 60  51   0]
#   [172 163 106]
#   ...
#   [143 132 124]
#   [163 153 146]
#   [178 167 163]]
#
#  [[ 66  59   4]
#   [125 115  61]
#   [238 228 174]
#   ...
#   [172 160 154]
#   [129 121 114]
#   [ 96  87  83]]]
# [255, 252, 252]

# %%
imgBlue = img[:,:,0]
imgGreen = img[:,:,1]
imgRed = img[:,:,2]

new_img = np.hstack((imgBlue, imgGreen, imgRed))
cv2_imshow(new_img)
cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=L size=720x180>
# -1

# %%
# Load the image in color mode (BGR is the default)
img = cv2.imread('/content/building.jpg')

# Check if the image was loaded successfully
if img is not None:
    # Split the image into its BGR channels
    imgBlue = img[:,:,0]
    imgGreen = img[:,:,1]
    imgRed = img[:,:,2]

    # Stack the channels horizontally
    new_img = np.hstack((imgBlue, imgGreen, imgRed))

    # Display the new image using cv2_imshow (suitable for Colab)
    cv2_imshow(new_img)
    # cv2.waitKey(0) # Not needed with cv2_imshow in Colab
    # cv2.destroyAllWindows() # Not needed with cv2_imshow in Colab
else:
    print("Error loading image.")
# Out:
# <PIL.Image.Image image mode=L size=720x180>

# %%
import cv2
from google.colab.patches import cv2_imshow

img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

cv2_imshow(img_gray)
# Out:
# <PIL.Image.Image image mode=L size=240x180>

# %%
img_flip = cv2.flip(img, 2)

cv2_imshow(img_flip)
# Out:
# <PIL.Image.Image image mode=RGB size=240x180>

# %%
img_crop = img[100:300, 200:500]

cv2_imshow(img_crop)
# Out:
# <PIL.Image.Image image mode=RGB size=40x80>
